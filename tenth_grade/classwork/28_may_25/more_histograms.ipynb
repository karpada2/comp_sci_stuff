# %%
import matplotlib.pyplot as plt
import statistics

data1 = [20, 22, 25, 28, 30, 35, 40, 45, 48, 50, 52, 55, 58, 60, 65, 68, 70, 72, 75, 78]
data2 = [40, 42, 45, 48, 50, 55, 60, 65, 68, 70, 72, 75, 78, 80, 85, 88, 90, 92, 95, 98]
data3 = [10, 15, 20, 22, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 77, 80, 85, 90, 95]
data4 = [60, 62, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 80, 82, 84]
data5 = [20, 25, 30, 33, 35, 40, 45, 50, 55, 60, 70, 80, 85, 90, 95, 100, 110, 120, 130, 150]

plt.boxplot(x=[data1, data2, data3, data4, data5], showmeans=True)
plt.grid()
plt.show()

# %%
import statistics
import matplotlib.pyplot as plt

Variety_A = [45, 48, 52, 46, 50, 49, 51, 47, 53, 44, 48, 50, 52, 46, 49, 47, 51, 48, 50, 45,
49, 52, 48, 46, 50, 47, 51, 49, 48, 53, 46, 50, 47, 52, 49, 48, 45, 51, 50, 47]
Variety_B = [38, 55, 42, 58, 40, 56, 44, 52, 39, 57, 43, 54, 41, 59, 45, 53, 39, 56, 42, 58,
44, 55, 40, 57, 43, 54, 38, 59, 41, 56, 45, 52, 42, 58, 39, 55, 44, 57, 40, 53]


plt.hist(Variety_A, 8, label="A", edgecolor="black", alpha=0.8)

plt.legend()
plt.grid()
plt.show()


plt.hist(Variety_B, 8, label="B", edgecolor="black", alpha=0.5)

plt.legend()
plt.grid()
plt.show()


print(f"A mean = {statistics.mean(Variety_A)}\nB mean = {statistics.mean(Variety_B)}")
print(f"A שונות = {statistics.stdev(Variety_A)**2}\nB שונות = {statistics.stdev(Variety_B)**2}")
print(f"A stdev = {statistics.stdev(Variety_A)}\nB stdev = {statistics.stdev(Variety_B)}")
# Out:
# 2.718281828459045
# A mean = 48.725
# B mean = 48.575
# A שונות = 5.6916666666666655
# B שונות = 56.968589743589746
# A stdev = 2.3857214143035783
# B stdev = 7.54775395356723

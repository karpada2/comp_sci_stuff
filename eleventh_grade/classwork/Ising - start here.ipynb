# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# parameters
T = 1
J = 1
k_B = 1
time = 100
Magnetism = []

all_grids = []    # Animation: grids for the animation

# grid diemnsions
N = 10         

for t in range(time):
    all_grids.append(grid.copy())    # Animation: save all grids before change

#### START HERE ####
    















### Plots and Animation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# ---- Animation ----

# create first image
all_grids.append(grid.copy())     # Animation: save all grids before change
im = ax1.imshow(all_grids[0], cmap='plasma', vmin=-1, vmax=1)
ax1.set_title("Ising model")
ax1.axis('off')

# crrate function to update the frames

def update(frame):
    im.set_array(all_grids[frame])  # change grid in frame
    ax1.set_title(f"Ising model - Time: {frame}")  # update title
    return [im]  # return changed image

# create animation
anim = FuncAnimation(fig, update, frames=len(all_grids), interval=100)
plt.close()

ax2.plot(range(time),Magnetism, label = 'Magnetism');
ax2.set_ylim(0,1)

HTML(anim.to_jshtml())  # show as html
# Out:
# 1
